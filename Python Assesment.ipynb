# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
car_df = pd.read_csv ("C:\\Users\\User\\Desktop\\Python Assesment Data\\car_prices.csv")
car_df
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer   color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0   white
# 1         automatic  5xyktca69fg561319    ca        5.0    9393.0   white
# 2         automatic  wba3c1c51ek116351    ca       45.0    1331.0    gray
# 3         automatic  yv1612tb4f1310987    ca       41.0   14282.0   white
# 4         automatic  wba6b2c57ed129731    ca       43.0    2641.0    gray
# ...             ...                ...   ...        ...       ...     ...
# 558832          NaN  knalw4d4xf6019304    in       45.0   18255.0  silver
# 558833    automatic  3c6td5et6cg112407    wa        5.0   54393.0   white
# 558834    automatic  5uxzw0c58cl668465    ca       48.0   50561.0   black
# 558835    automatic  1n4al3ap0fc216050    ga       38.0   16658.0   white
# 558836    automatic  1ftfw1et2eke87277    ca       34.0   15008.0    gray
#
#        interior                                             seller      mmr  \
# 0         black                            kia motors america  inc  20500.0
# 1         beige                            kia motors america  inc  20800.0
# 2         black             financial services remarketing (lease)  31900.0
# 3         black                            volvo na rep/world omni  27500.0
# 4         black             financial services remarketing (lease)  66000.0
# ...         ...                                                ...      ...
# 558832    black                                   avis corporation  35300.0
# 558833    black                                    i -5 uhlmann rv  30200.0
# 558834    black             financial services remarketing (lease)  29800.0
# 558835    black  enterprise vehicle exchange / tra / rental / t...  15100.0
# 558836     gray                   ford motor credit company llc pd  29600.0
#
#         sellingprice                                 saledate
# 0            21500.0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)
# 1            21500.0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)
# 2            30000.0  Thu Jan 15 2015 04:30:00 GMT-0800 (PST)
# 3            27750.0  Thu Jan 29 2015 04:30:00 GMT-0800 (PST)
# 4            67000.0  Thu Dec 18 2014 12:30:00 GMT-0800 (PST)
# ...              ...                                      ...
# 558832       33000.0  Thu Jul 09 2015 07:00:00 GMT-0700 (PDT)
# 558833       30800.0  Wed Jul 08 2015 09:30:00 GMT-0700 (PDT)
# 558834       34000.0  Wed Jul 08 2015 09:30:00 GMT-0700 (PDT)
# 558835       11100.0  Thu Jul 09 2015 06:45:00 GMT-0700 (PDT)
# 558836       26700.0  Thu May 28 2015 05:30:00 GMT-0700 (PDT)
#
# [558837 rows x 16 columns]

# %%
#Display the first 5 rows
car_df.head()
# Out:
#    year   make                model        trim   body transmission  \
# 0  2015    Kia              Sorento          LX    SUV    automatic
# 1  2015    Kia              Sorento          LX    SUV    automatic
# 2  2014    BMW             3 Series  328i SULEV  Sedan    automatic
# 3  2015  Volvo                  S60          T5  Sedan    automatic
# 4  2014    BMW  6 Series Gran Coupe        650i  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0   16639.0  white    black
# 1  5xyktca69fg561319    ca        5.0    9393.0  white    beige
# 2  wba3c1c51ek116351    ca       45.0    1331.0   gray    black
# 3  yv1612tb4f1310987    ca       41.0   14282.0  white    black
# 4  wba6b2c57ed129731    ca       43.0    2641.0   gray    black
#
#                                    seller      mmr  sellingprice  \
# 0                 kia motors america  inc  20500.0       21500.0
# 1                 kia motors america  inc  20800.0       21500.0
# 2  financial services remarketing (lease)  31900.0       30000.0
# 3                 volvo na rep/world omni  27500.0       27750.0
# 4  financial services remarketing (lease)  66000.0       67000.0
#
#                                   saledate
# 0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)
# 1  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)
# 2  Thu Jan 15 2015 04:30:00 GMT-0800 (PST)
# 3  Thu Jan 29 2015 04:30:00 GMT-0800 (PST)
# 4  Thu Dec 18 2014 12:30:00 GMT-0800 (PST)

# %%
#Display data types and record count. 
print(car_df.dtypes)
# Out:
# year              int64
# make             object
# model            object
# trim             object
# body             object
# transmission     object
# vin              object
# state            object
# condition       float64
# odometer        float64
# color            object
# interior         object
# seller           object
# mmr             float64
# sellingprice    float64
# saledate         object
# dtype: object

# %%
#Display data types and record count.
#Display column names and data types. 
car_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558837 entries, 0 to 558836
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          558837 non-null  int64
#  1   make          548536 non-null  object
#  2   model         548438 non-null  object
#  3   trim          548186 non-null  object
#  4   body          545642 non-null  object
#  5   transmission  493485 non-null  object
#  6   vin           558833 non-null  object
#  7   state         558837 non-null  object
#  8   condition     547017 non-null  float64
#  9   odometer      558743 non-null  float64
#  10  color         558088 non-null  object
#  11  interior      558088 non-null  object
#  12  seller        558837 non-null  object
#  13  mmr           558799 non-null  float64
#  14  sellingprice  558825 non-null  float64
#  15  saledate      558825 non-null  object
# dtypes: float64(4), int64(1), object(11)
# memory usage: 68.2+ MB

# %%
print(len(car_df))
# Out:
# 558837

# %%
#Check the shape of the dataset (rows and columns).
print(car_df.shape)
# Out:
# (558837, 16)

# %%
#Quantify nulls per column; visualize with a bar chart or heatmap. 
null_count = car_df.isnull().sum()
print(null_count)
# Out:
# year                0
# make            10301
# model           10399
# trim            10651
# body            13195
# transmission    65352
# vin                 4
# state               0
# condition       11820
# odometer           94
# color             749
# interior          749
# seller              0
# mmr                38
# sellingprice       12
# saledate           12
# dtype: int64

# %%
#Quantify nulls per column; visualize with a bar chart or heatmap. 
plt.figure(figsize = (16,9))
plt.bar(null_count.index,null_count.values, color = "green",width = 0.1)
plt.xlabel('column Names')
plt.ylabel('Number of Null Values')
plt.title('Null Values per Column')
# Out:
# Text(0.5, 1.0, 'Null Values per Column')

# %%
car_df["make"].mode()
# Out:
# 0    Ford
# Name: make, dtype: object

# %%
car_df["model"].mode()
# Out:
# 0    Altima
# Name: model, dtype: object

# %%
car_df["trim"].mode()
# Out:
# 0    Base
# Name: trim, dtype: object

# %%
car_df["body"].mode()
# Out:
# 0    Sedan
# Name: body, dtype: object

# %%
car_df["transmission"].mode()
# Out:
# 0    automatic
# Name: transmission, dtype: object

# %%
car_df["vin"].mode()
# Out:
# 0    automatic
# Name: vin, dtype: object

# %%
car_df["condition"].median()
# Out:
# 35.0

# %%
car_df["odometer"].median()
# Out:
# 52254.0

# %%
car_df["color"].mode()
# Out:
# 0    black
# Name: color, dtype: object

# %%
car_df["interior"].mode()
# Out:
# 0    black
# Name: interior, dtype: object

# %%
car_df["mmr"].median()
# Out:
# 12250.0

# %%
car_df["sellingprice"].mean().round(1)
# Out:
# 13611.4

# %%
car_df["saledate"].mode()
# Out:
# 0    Tue Feb 10 2015 01:30:00 GMT-0800 (PST)
# Name: saledate, dtype: object

# %%
#Resolve null values by appropriate strategy based on the datatype and percentage of null values.
car_df1 = car_df.fillna({"make" : "Ford","model" : "Altima", "trim" : "Base","body" : "Sedan","transmission" : "automatic","vin" : "automatic",
               "condition" : 35.0,"odometer" : 52254.0,"color" : "black","interior" : "black","mmr" : 12250.0,"sellingprice" : 13611.4,
               "saledate" : "Tue Feb 10 2015 01:30:00 GMT-0800 (PST)"})
car_df1
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer   color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0   white
# 1         automatic  5xyktca69fg561319    ca        5.0    9393.0   white
# 2         automatic  wba3c1c51ek116351    ca       45.0    1331.0    gray
# 3         automatic  yv1612tb4f1310987    ca       41.0   14282.0   white
# 4         automatic  wba6b2c57ed129731    ca       43.0    2641.0    gray
# ...             ...                ...   ...        ...       ...     ...
# 558832    automatic  knalw4d4xf6019304    in       45.0   18255.0  silver
# 558833    automatic  3c6td5et6cg112407    wa        5.0   54393.0   white
# 558834    automatic  5uxzw0c58cl668465    ca       48.0   50561.0   black
# 558835    automatic  1n4al3ap0fc216050    ga       38.0   16658.0   white
# 558836    automatic  1ftfw1et2eke87277    ca       34.0   15008.0    gray
#
#        interior                                             seller      mmr  \
# 0         black                            kia motors america  inc  20500.0
# 1         beige                            kia motors america  inc  20800.0
# 2         black             financial services remarketing (lease)  31900.0
# 3         black                            volvo na rep/world omni  27500.0
# 4         black             financial services remarketing (lease)  66000.0
# ...         ...                                                ...      ...
# 558832    black                                   avis corporation  35300.0
# 558833    black                                    i -5 uhlmann rv  30200.0
# 558834    black             financial services remarketing (lease)  29800.0
# 558835    black  enterprise vehicle exchange / tra / rental / t...  15100.0
# 558836     gray                   ford motor credit company llc pd  29600.0
#
#         sellingprice                                 saledate
# 0            21500.0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)
# 1            21500.0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)
# 2            30000.0  Thu Jan 15 2015 04:30:00 GMT-0800 (PST)
# 3            27750.0  Thu Jan 29 2015 04:30:00 GMT-0800 (PST)
# 4            67000.0  Thu Dec 18 2014 12:30:00 GMT-0800 (PST)
# ...              ...                                      ...
# 558832       33000.0  Thu Jul 09 2015 07:00:00 GMT-0700 (PDT)
# 558833       30800.0  Wed Jul 08 2015 09:30:00 GMT-0700 (PDT)
# 558834       34000.0  Wed Jul 08 2015 09:30:00 GMT-0700 (PDT)
# 558835       11100.0  Thu Jul 09 2015 06:45:00 GMT-0700 (PDT)
# 558836       26700.0  Thu May 28 2015 05:30:00 GMT-0700 (PDT)
#
# [558837 rows x 16 columns]

# %%
#Resolve null values by appropriate strategy based on the datatype and percentage of null values.
car_df1.isnull().sum()
# Out:
# year            0
# make            0
# model           0
# trim            0
# body            0
# transmission    0
# vin             0
# state           0
# condition       0
# odometer        0
# color           0
# interior        0
# seller          0
# mmr             0
# sellingprice    0
# saledate        0
# dtype: int64

# %%
#Count number of duplicate records and delete if any present
car_df1.duplicated().sum()
# Out:
# 0

# %%
#2.1 Calculate the average, minimum, and maximum car price?
car_df["sellingprice"].mean().round(1)
# Out:
# 13611.4

# %%
#2.1 Calculate the average, minimum, and maximum car price?
car_df["sellingprice"].max()
# Out:
# 230000.0

# %%
#2.1 Calculate the average, minimum, and maximum car price?
car_df["sellingprice"].min()
car_df
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer   color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0   white
# 1         automatic  5xyktca69fg561319    ca        5.0    9393.0   white
# 2         automatic  wba3c1c51ek116351    ca       45.0    1331.0    gray
# 3         automatic  yv1612tb4f1310987    ca       41.0   14282.0   white
# 4         automatic  wba6b2c57ed129731    ca       43.0    2641.0    gray
# ...             ...                ...   ...        ...       ...     ...
# 558832          NaN  knalw4d4xf6019304    in       45.0   18255.0  silver
# 558833    automatic  3c6td5et6cg112407    wa        5.0   54393.0   white
# 558834    automatic  5uxzw0c58cl668465    ca       48.0   50561.0   black
# 558835    automatic  1n4al3ap0fc216050    ga       38.0   16658.0   white
# 558836    automatic  1ftfw1et2eke87277    ca       34.0   15008.0    gray
#
#        interior                                             seller      mmr  \
# 0         black                            kia motors america  inc  20500.0
# 1         beige                            kia motors america  inc  20800.0
# 2         black             financial services remarketing (lease)  31900.0
# 3         black                            volvo na rep/world omni  27500.0
# 4         black             financial services remarketing (lease)  66000.0
# ...         ...                                                ...      ...
# 558832    black                                   avis corporation  35300.0
# 558833    black                                    i -5 uhlmann rv  30200.0
# 558834    black             financial services remarketing (lease)  29800.0
# 558835    black  enterprise vehicle exchange / tra / rental / t...  15100.0
# 558836     gray                   ford motor credit company llc pd  29600.0
#
#         sellingprice                                 saledate
# 0            21500.0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)
# 1            21500.0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)
# 2            30000.0  Thu Jan 15 2015 04:30:00 GMT-0800 (PST)
# 3            27750.0  Thu Jan 29 2015 04:30:00 GMT-0800 (PST)
# 4            67000.0  Thu Dec 18 2014 12:30:00 GMT-0800 (PST)
# ...              ...                                      ...
# 558832       33000.0  Thu Jul 09 2015 07:00:00 GMT-0700 (PDT)
# 558833       30800.0  Wed Jul 08 2015 09:30:00 GMT-0700 (PDT)
# 558834       34000.0  Wed Jul 08 2015 09:30:00 GMT-0700 (PDT)
# 558835       11100.0  Thu Jul 09 2015 06:45:00 GMT-0700 (PDT)
# 558836       26700.0  Thu May 28 2015 05:30:00 GMT-0700 (PDT)
#
# [558837 rows x 16 columns]

# %%
#2.2 List all unique colors of cars? 
car_df["color"].unique()
# Out:
# array(['white', 'gray', 'black', 'red', 'silver', 'blue', 'brown',
#        'beige', 'purple', 'burgundy', '—', 'gold', 'yellow', 'green',
#        'charcoal', nan, 'orange', 'off-white', 'turquoise', 'pink',
#        'lime', '4802', '9410', '1167', '2172', '14872', '12655', '15719',
#        '6388', '16633', '11034', '2711', '6864', '339', '18384', '9887',
#        '9837', '20379', '20627', '721', '6158', '2817', '5705', '18561',
#        '2846', '9562', '5001'], dtype=object)

# %%
#2.2 List all unique colors of cars? 
car_df["color"].value_counts()
# Out:
# color
# black        110970
# white        106673
# silver        83389
# gray          82857
# blue          51139
# red           43569
# —             24685
# green         11382
# gold          11342
# beige          9222
# burgundy       8972
# brown          6717
# orange         2078
# purple         1561
# off-white      1449
# yellow         1285
# charcoal        479
# turquoise       236
# pink             42
# lime             15
# 9562              1
# 2846              1
# 18561             1
# 18384             1
# 5705              1
# 2817              1
# 6158              1
# 721               1
# 20627             1
# 20379             1
# 9837              1
# 9887              1
# 2172              1
# 339               1
# 6864              1
# 2711              1
# 11034             1
# 16633             1
# 6388              1
# 15719             1
# 12655             1
# 14872             1
# 1167              1
# 9410              1
# 4802              1
# 5001              1
# Name: count, dtype: int64

# %%
#2.3 Find the number of unique car brands and car models?
len(car_df1['make'].unique())
# Out:
# 96

# %%
#2.3 Find the number of unique car brands and car models?
len(car_df1['model'].unique())
# Out:
# 973

# %%
#2.4 Find all car information having selling prices greater than $165000? 
car_df1[car_df1["sellingprice"] > 165000]
# Out:
#         year           make       model      trim   body transmission  \
# 125095  2012    Rolls-Royce       Ghost      Base  Sedan    automatic
# 344905  2014           Ford      Escape  Titanium    SUV    automatic
# 446949  2015  Mercedes-Benz     S-Class   S65 AMG  Sedan    automatic
# 538347  2012    Rolls-Royce       Ghost      Base  sedan    automatic
# 545523  2013    Rolls-Royce       Ghost      Base  sedan    automatic
# 548169  2011        Ferrari  458 Italia      Base  coupe    automatic
# 557570  2012    Rolls-Royce       Ghost       EWB  sedan    automatic
#
#                       vin state  condition  odometer  color interior  \
# 125095  sca664s58cux50727    fl       45.0   14316.0  black    beige
# 344905  1fmcu9j98eua23833    mo       43.0   27802.0  green      tan
# 446949  wddug7kb2fa102347    ca       41.0    5277.0  white    white
# 538347  sca664s59cux50803    ca       44.0    5215.0  white      tan
# 545523  sca664s52dux52152    fl       42.0    7852.0  white    beige
# 548169  zff67nfa1b0178698    fl       46.0   12116.0    red    black
# 557570  sca664l50cux65625    ca       36.0   11832.0  white    black
#
#                                           seller       mmr  sellingprice  \
# 125095                          braman motorcars  154000.0      169500.0
# 344905               ford-lincoln dealer program   22800.0      230000.0
# 446949                         mercedes-benz usa  170000.0      173000.0
# 538347  financial services remarketing (bmw int)  166000.0      167000.0
# 545523                flag/landrover southpointe  178000.0      171500.0
# 548169                       platinum motor cars  182000.0      183000.0
# 557570                        bentley scottsdale  164000.0      169000.0
#
#                                        saledate
# 125095  Wed Jan 14 2015 01:40:00 GMT-0800 (PST)
# 344905  Wed Feb 25 2015 02:00:00 GMT-0800 (PST)
# 446949  Thu May 21 2015 05:00:00 GMT-0700 (PDT)
# 538347  Thu Jun 18 2015 05:30:00 GMT-0700 (PDT)
# 545523  Wed Jun 17 2015 03:05:00 GMT-0700 (PDT)
# 548169  Wed Jun 17 2015 03:40:00 GMT-0700 (PDT)
# 557570  Thu Jun 18 2015 05:30:00 GMT-0700 (PDT)

# %%
#2.5 Find the top 5 most frequently sold car models?

car_df1['model'].value_counts().head(5)
# Out:
# model
# Altima    29748
# F-150     14479
# Fusion    12946
# Camry     12545
# Escape    11861
# Name: count, dtype: int64

# %%
#2.6 What is the average selling price of cars by brand (make)? 

car_df1[["make","sellingprice"]].groupby("make").mean()
# Out:
#               sellingprice
# make
# Acura         14017.268260
# Aston Martin  54812.000000
# Audi          19915.432782
# BMW           21441.895748
# Bentley       74367.672414
# ...                    ...
# subaru         3710.416667
# suzuki         4810.000000
# toyota         7339.105263
# volkswagen     6145.833333
# vw            13672.916667
#
# [96 rows x 1 columns]

# %%
#2.7 What is the minimum selling price of cars for each interior? 

car_df1[["interior","sellingprice"]].groupby("interior").min()
# Out:
#            sellingprice
# interior
# beige             100.0
# black               1.0
# blue              150.0
# brown             200.0
# burgundy          175.0
# gold              250.0
# gray                1.0
# green             100.0
# off-white         900.0
# orange           1200.0
# purple            200.0
# red               200.0
# silver            150.0
# tan               100.0
# white             350.0
# yellow           3100.0
# —                 150.0

# %%
#2.8 Find highest odometer reading per year from highest to lowest order? 

highest_odometer = car_df1[["year","odometer"]].groupby("year").max()
print(highest_odometer)
# Out:
#       odometer
# year
# 1982   85738.0
# 1983   42697.0
# 1984  170799.0
# 1985  121644.0
# 1986  273327.0
# 1987  230946.0
# 1988  241751.0
# 1989  218052.0
# 1990  265498.0
# 1991  274149.0
# 1992  379307.0
# 1993  999999.0
# 1994  356402.0
# 1995  396793.0
# 1996  999999.0
# 1997  999999.0
# 1998  999999.0
# 1999  999999.0
# 2000  462579.0
# 2001  999999.0
# 2002  999999.0
# 2003  999999.0
# 2004  999999.0
# 2005  999999.0
# 2006  999999.0
# 2007  999999.0
# 2008  999999.0
# 2009  999999.0
# 2010  999999.0
# 2011  999999.0
# 2012  999999.0
# 2013  999999.0
# 2014  999999.0
# 2015  100454.0

# %%
#2.8 Find highest odometer reading per year from highest to lowest order? 

highest_odometer.sort_values("year",ascending = False)
# Out:
#       odometer
# year
# 2015  100454.0
# 2014  999999.0
# 2013  999999.0
# 2012  999999.0
# 2011  999999.0
# 2010  999999.0
# 2009  999999.0
# 2008  999999.0
# 2007  999999.0
# 2006  999999.0
# 2005  999999.0
# 2004  999999.0
# 2003  999999.0
# 2002  999999.0
# 2001  999999.0
# 2000  462579.0
# 1999  999999.0
# 1998  999999.0
# 1997  999999.0
# 1996  999999.0
# 1995  396793.0
# 1994  356402.0
# 1993  999999.0
# 1992  379307.0
# 1991  274149.0
# 1990  265498.0
# 1989  218052.0
# 1988  241751.0
# 1987  230946.0
# 1986  273327.0
# 1985  121644.0
# 1984  170799.0
# 1983   42697.0
# 1982   85738.0

# %%
#2.9 Create a new column for car age (assuming the current year is 2025)

car_df1['car_age'] = 2025 - car_df1['year']

# %%
##2.9 Create a new column for car age (assuming the current year is 2025)

car_df1.head()
# Out:
#    year   make                model        trim   body transmission  \
# 0  2015    Kia              Sorento          LX    SUV    automatic
# 1  2015    Kia              Sorento          LX    SUV    automatic
# 2  2014    BMW             3 Series  328i SULEV  Sedan    automatic
# 3  2015  Volvo                  S60          T5  Sedan    automatic
# 4  2014    BMW  6 Series Gran Coupe        650i  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0   16639.0  white    black
# 1  5xyktca69fg561319    ca        5.0    9393.0  white    beige
# 2  wba3c1c51ek116351    ca       45.0    1331.0   gray    black
# 3  yv1612tb4f1310987    ca       41.0   14282.0  white    black
# 4  wba6b2c57ed129731    ca       43.0    2641.0   gray    black
#
#                                    seller      mmr  sellingprice  \
# 0                 kia motors america  inc  20500.0       21500.0
# 1                 kia motors america  inc  20800.0       21500.0
# 2  financial services remarketing (lease)  31900.0       30000.0
# 3                 volvo na rep/world omni  27500.0       27750.0
# 4  financial services remarketing (lease)  66000.0       67000.0
#
#                                   saledate  car_age
# 0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)       10
# 1  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)       10
# 2  Thu Jan 15 2015 04:30:00 GMT-0800 (PST)       11
# 3  Thu Jan 29 2015 04:30:00 GMT-0800 (PST)       10
# 4  Thu Dec 18 2014 12:30:00 GMT-0800 (PST)       11

# %%
#2.10 Find the number of cars having a condition greater than or equal to 48 and odometer greater than 90000? 

car_df1[(car_df1["condition"] >= 48.0) & (car_df1["odometer"] > 90000)]
# Out:
#         year           make             model           trim      body  \
# 3230    2008         HUMMER                H3           Base       SUV
# 3767    2006      Chevrolet    Silverado 1500            LS2  Crew Cab
# 4365    2005         Toyota           4Runner            SR5       SUV
# 6743    2010  Mercedes-Benz           M-Class  ML350 BlueTEC       SUV
# 9814    2011          Honda            Accord         EX V-6     Sedan
# ...      ...            ...               ...            ...       ...
# 554633  2007          Acura               MDX           Base       suv
# 554693  2007         HUMMER                H3           Base       suv
# 556010  2008           Ford  F-350 Super Duty            XLT  crew cab
# 556929  2010            GMC            Acadia          SLT-2       suv
# 556953  2010  Mercedes-Benz          GL-Class   GL450 4MATIC       suv
#
#        transmission                vin state  condition  odometer     color  \
# 3230      automatic  5gten13e588135632    ca       48.0   91132.0     black
# 3767      automatic  2gcec13v561250941    ca       49.0   97742.0     white
# 4365      automatic  jtebu14rx50077814    ca       48.0  155887.0      gray
# 6743      automatic  4jgbb2fb8aa608119    ca       49.0   92966.0         —
# 9814      automatic  5kbcp3f7xbb001435    in       48.0   93763.0      gray
# ...             ...                ...   ...        ...       ...       ...
# 554633    automatic  2hnyd28497h546449    ca       48.0  113131.0      gray
# 554693    automatic  5gtdn13e178219652    wa       48.0  113993.0      blue
# 556010    automatic  1ftww31rx8ed16463    pa       48.0   92268.0  charcoal
# 556929    automatic  1gklvned1aj221405    pa       49.0  113337.0  burgundy
# 556953    automatic  4jgbf7be7aa597373    ga       49.0  112638.0     black
#
#        interior                                     seller      mmr  \
# 3230      beige                               apexcars net  11950.0
# 3767       gray                      coast sports cars inc   8800.0
# 4365       gray                      san diego sports cars   6850.0
# 6743      black                         clear view systems  19550.0
# 9814       gray  primeritus remarketing/new concepts leasi  11450.0
# ...         ...                                        ...      ...
# 554633     gray                  california auto wholesale  12450.0
# 554693    beige           remarketing by ge/manheim dallas  10950.0
# 556010    beige               r hollenshead auto sales inc  18850.0
# 556929    beige                      jones dealerships inc  14300.0
# 556953      tan                         momentum motorcars  20000.0
#
#         sellingprice                                 saledate  car_age
# 3230         15300.0  Wed Dec 17 2014 12:30:00 GMT-0800 (PST)       17
# 3767         13250.0  Wed Dec 17 2014 12:15:00 GMT-0800 (PST)       19
# 4365          9500.0  Wed Dec 17 2014 12:15:00 GMT-0800 (PST)       20
# 6743         19250.0  Tue Dec 23 2014 12:30:00 GMT-0800 (PST)       15
# 9814          9000.0  Thu Dec 18 2014 10:00:00 GMT-0800 (PST)       14
# ...              ...                                      ...      ...
# 554633       15500.0  Wed Jun 17 2015 05:30:00 GMT-0700 (PDT)       18
# 554693        9500.0  Wed Jun 17 2015 05:00:00 GMT-0700 (PDT)       18
# 556010       23400.0  Fri Jun 19 2015 02:00:00 GMT-0700 (PDT)       17
# 556929       13100.0  Fri Jun 19 2015 02:00:00 GMT-0700 (PDT)       15
# 556953       21600.0  Thu Jun 18 2015 03:00:00 GMT-0700 (PDT)       15
#
# [746 rows x 17 columns]

# %%
#2.11 Which state consistently has higher car prices for newer cars(year>2013)?

new_car = car_df1[car_df1['year'] >2013]
new_car
# Out:
#         year    make                model        trim       body transmission  \
# 0       2015     Kia              Sorento          LX        SUV    automatic
# 1       2015     Kia              Sorento          LX        SUV    automatic
# 2       2014     BMW             3 Series  328i SULEV      Sedan    automatic
# 3       2015   Volvo                  S60          T5      Sedan    automatic
# 4       2014     BMW  6 Series Gran Coupe        650i      Sedan    automatic
# ...      ...     ...                  ...         ...        ...          ...
# 558826  2014    Jeep       Grand Cherokee     Limited        SUV    automatic
# 558827  2014    Jeep       Grand Cherokee      Laredo        SUV    automatic
# 558832  2015     Kia                 K900      Luxury      Sedan    automatic
# 558835  2015  Nissan               Altima       2.5 S      sedan    automatic
# 558836  2014    Ford                F-150         XLT  SuperCrew    automatic
#
#                       vin state  condition  odometer   color interior  \
# 0       5xyktca69fg566472    ca        5.0   16639.0   white    black
# 1       5xyktca69fg561319    ca        5.0    9393.0   white    beige
# 2       wba3c1c51ek116351    ca       45.0    1331.0    gray    black
# 3       yv1612tb4f1310987    ca       41.0   14282.0   white    black
# 4       wba6b2c57ed129731    ca       43.0    2641.0    gray    black
# ...                   ...   ...        ...       ...     ...      ...
# 558826  1c4rjebg4ec573100    ca       44.0    9024.0    gray    black
# 558827  1c4rjfag0ec466276    pa       42.0   25180.0    gray    black
# 558832  knalw4d4xf6019304    in       45.0   18255.0  silver    black
# 558835  1n4al3ap0fc216050    ga       38.0   16658.0   white    black
# 558836  1ftfw1et2eke87277    ca       34.0   15008.0    gray     gray
#
#                                                    seller      mmr  \
# 0                                 kia motors america  inc  20500.0
# 1                                 kia motors america  inc  20800.0
# 2                  financial services remarketing (lease)  31900.0
# 3                                 volvo na rep/world omni  27500.0
# 4                  financial services remarketing (lease)  66000.0
# ...                                                   ...      ...
# 558826  enterprise vehicle exchange / tra / rental / t...  29800.0
# 558827                              hertz corporation/gdp  26000.0
# 558832                                   avis corporation  35300.0
# 558835  enterprise vehicle exchange / tra / rental / t...  15100.0
# 558836                   ford motor credit company llc pd  29600.0
#
#         sellingprice                                 saledate  car_age
# 0            21500.0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)       10
# 1            21500.0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)       10
# 2            30000.0  Thu Jan 15 2015 04:30:00 GMT-0800 (PST)       11
# 3            27750.0  Thu Jan 29 2015 04:30:00 GMT-0800 (PST)       10
# 4            67000.0  Thu Dec 18 2014 12:30:00 GMT-0800 (PST)       11
# ...              ...                                      ...      ...
# 558826       17300.0  Thu Jul 09 2015 09:00:00 GMT-0700 (PDT)       11
# 558827       24500.0  Tue Jul 07 2015 06:30:00 GMT-0700 (PDT)       11
# 558832       33000.0  Thu Jul 09 2015 07:00:00 GMT-0700 (PDT)       10
# 558835       11100.0  Thu Jul 09 2015 06:45:00 GMT-0700 (PDT)       10
# 558836       26700.0  Thu May 28 2015 05:30:00 GMT-0700 (PDT)       11
#
# [90507 rows x 17 columns]

# %%
#2.11 Which state consistently has higher car prices for newer cars(year>2013)? 

higher_price = new_car[["state","sellingprice"]].groupby("state").mean()
higher_price
# Out:
#                    sellingprice
# state
# 3vwd17aj0fm227318  13700.000000
# 3vwd17aj2fm258506  13300.000000
# 3vwd17aj2fm261566  13400.000000
# 3vwd17aj2fm285365  14050.000000
# 3vwd17aj3fm259017  14250.000000
# ...                         ...
# tx                 19889.826278
# ut                 18794.512195
# va                 19114.263125
# wa                 20598.724947
# wi                 19266.265248
#
# [64 rows x 1 columns]

# %%
#2.11 Which state consistently has higher car prices for newer cars(year>2013)? 

higher_price.sort_values("sellingprice",ascending = False)
# Out:
#                    sellingprice
# state
# oh                 28020.221053
# ab                 25204.255319
# nj                 24237.063973
# on                 22962.560386
# qc                 22722.938144
# ...                         ...
# 3vwd17aj5fm225953  13200.000000
# 3vwd17aj8fm239622  13200.000000
# 3vwd17aj4fm201708  13200.000000
# 3vwd17aj3fm276741  13200.000000
# ok                 10600.000000
#
# [64 rows x 1 columns]

# %%
#2.12 For cars with excellent condition (top 20%), which makes have the lowest average price (value for money)?

top_condition = car_df1["condition"].quantile(0.80)

# %%
##2.12 For cars with excellent condition (top 20%), which makes have the lowest average price (value for money)?

top_car = car_df1[car_df1["condition"] >= top_condition]

# %%
##2.12 For cars with excellent condition (top 20%), which makes have the lowest average price (value for money)?

average_price = top_car[["make","sellingprice"]].groupby("make").mean()

# %%
##2.12 For cars with excellent condition (top 20%), which makes have the lowest average price (value for money)?

value_money = average_price.sort_values("make", ascending = True)

# %%
##2.12 For cars with excellent condition (top 20%), which makes have the lowest average price (value for money)?

value_money.head()
# Out:
#               sellingprice
# make
# Acura         23295.343840
# Aston Martin  59125.000000
# Audi          31917.639485
# BMW           32242.705077
# Bentley       96040.000000

# %%
#3.1 Show the correlation of all the features(columns) having numerical values(e.g. selling price, odometer)

plt.figure(figsize=(10, 6))
sns.heatmap(car_df1.select_dtypes(include=['float64', 'int64']).corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap of Numeric Columns")
plt.tight_layout()
plt.show()

# %%
#3.2 Plot a graph to show the average selling price by year and explain the pattern you notice from the graph. Which plot will you use bar or scatter?

Average_Selling_price = car_df1[["year","sellingprice"]].groupby("year").mean().reset_index()

Average_Selling_price
# Out:
#     year  sellingprice
# 0   1982  12750.000000
# 1   1983   5250.000000
# 2   1984   2160.000000
# 3   1985   3520.000000
# 4   1986   2538.636364
# 5   1987   1512.500000
# 6   1988   3168.181818
# 7   1989   1620.000000
# 8   1990   1435.714286
# 9   1991    943.656716
# 10  1992    991.666667
# 11  1993    833.902439
# 12  1994    870.599490
# 13  1995    913.292546
# 14  1996    985.781434
# 15  1997   1157.454722
# 16  1998   1261.719404
# 17  1999   1533.696105
# 18  2000   1827.834130
# 19  2001   2131.014224
# 20  2002   2611.709315
# 21  2003   3447.268654
# 22  2004   4321.474455
# 23  2005   4893.989857
# 24  2006   6190.204808
# 25  2007   8021.969687
# 26  2008   9508.054092
# 27  2009  10462.313295
# 28  2010  12412.453313
# 29  2011  15851.677185
# 30  2012  16653.690366
# 31  2013  17476.287713
# 32  2014  20090.040703
# 33  2015  25932.117198

# %%
#3.2 Plot a graph to show the average selling price by year and explain the pattern you notice from the graph. Which plot will you use bar or scatter?
# 1. We used a bar plot
# 2. We are comparing average values by categories [ Year & Selling Price ]

#Pattern Notice
#1. Year 2014 & 2015 have much higher average selling prices.
#2. In year 1982 the average selling price show higher bar graph & from year 1983 it started dropping till year 2010.
#3. From year 2011 shows increase in average selling prices.

plt.figure(figsize = (12,7))
plt.bar(Average_Selling_price['year'],Average_Selling_price['sellingprice'],color = 'Green',width = 0.3)
plt.title('Average Selling Price By Year')
plt.xlabel('Year')
plt.ylabel('Average Selling Price')
plt.xticks(Average_Selling_price['year'],rotation=45)
# Out:
# ([<matplotlib.axis.XTick at 0x21e57390b30>,
#   <matplotlib.axis.XTick at 0x21e57390110>,
#   <matplotlib.axis.XTick at 0x21e573a6b40>,
#   <matplotlib.axis.XTick at 0x21e57414bf0>,
#   <matplotlib.axis.XTick at 0x21e57415490>,
#   <matplotlib.axis.XTick at 0x21e57415cd0>,
#   <matplotlib.axis.XTick at 0x21e574156a0>,
#   <matplotlib.axis.XTick at 0x21e574167b0>,
#   <matplotlib.axis.XTick at 0x21e57417050>,
#   <matplotlib.axis.XTick at 0x21e57417950>,
#   <matplotlib.axis.XTick at 0x21e5767c1a0>,
#   <matplotlib.axis.XTick at 0x21e574172f0>,
#   <matplotlib.axis.XTick at 0x21e5767c800>,
#   <matplotlib.axis.XTick at 0x21e5767d100>,
#   <matplotlib.axis.XTick at 0x21e5767da00>,
#   <matplotlib.axis.XTick at 0x21e5767e330>,
#   <matplotlib.axis.XTick at 0x21e57393380>,
#   <matplotlib.axis.XTick at 0x21e5767d670>,
#   <matplotlib.axis.XTick at 0x21e5767f230>,
#   <matplotlib.axis.XTick at 0x21e5767fb30>,
#   <matplotlib.axis.XTick at 0x21e57698470>,
#   <matplotlib.axis.XTick at 0x21e57698dd0>,
#   <matplotlib.axis.XTick at 0x21e5767e4e0>,
#   <matplotlib.axis.XTick at 0x21e57699430>,
#   <matplotlib.axis.XTick at 0x21e57699d30>,
#   <matplotlib.axis.XTick at 0x21e5769a6c0>,
#   <matplotlib.axis.XTick at 0x21e5769af60>,
#   <matplotlib.axis.XTick at 0x21e5767e690>,
#   <matplotlib.axis.XTick at 0x21e57699f10>,
#   <matplotlib.axis.XTick at 0x21e5769b920>,
#   <matplotlib.axis.XTick at 0x21e576c02c0>,
#   <matplotlib.axis.XTick at 0x21e576c0b60>,
#   <matplotlib.axis.XTick at 0x21e576c1490>,
#   <matplotlib.axis.XTick at 0x21e573a4ad0>],
#  [Text(1982, 0, '1982'),
#   Text(1983, 0, '1983'),
#   Text(1984, 0, '1984'),
#   Text(1985, 0, '1985'),
#   Text(1986, 0, '1986'),
#   Text(1987, 0, '1987'),
#   Text(1988, 0, '1988'),
#   Text(1989, 0, '1989'),
#   Text(1990, 0, '1990'),
#   Text(1991, 0, '1991'),
#   Text(1992, 0, '1992'),
#   Text(1993, 0, '1993'),
#   Text(1994, 0, '1994'),
#   Text(1995, 0, '1995'),
#   Text(1996, 0, '1996'),
#   Text(1997, 0, '1997'),
#   Text(1998, 0, '1998'),
#   Text(1999, 0, '1999'),
#   Text(2000, 0, '2000'),
#   Text(2001, 0, '2001'),
#   Text(2002, 0, '2002'),
#   Text(2003, 0, '2003'),
#   Text(2004, 0, '2004'),
#   Text(2005, 0, '2005'),
#   Text(2006, 0, '2006'),
#   Text(2007, 0, '2007'),
#   Text(2008, 0, '2008'),
#   Text(2009, 0, '2009'),
#   Text(2010, 0, '2010'),
#   Text(2011, 0, '2011'),
#   Text(2012, 0, '2012'),
#   Text(2013, 0, '2013'),
#   Text(2014, 0, '2014'),
#   Text(2015, 0, '2015')])

# %%
#3.3 Plot a graph to show average selling price by odometer and explain the trend you notice from the graph.

# Trend Notice
# 1. As the odometer increase the selling price decrease.

plt.figure(figsize = (16,8))
plt.scatter(car_df1['odometer'],car_df1['sellingprice'],color = 'Green', marker  = "o")
plt.title ('Average Selling Prive Vs Odometer Reading')
plt.xlabel('Odometer')
plt.ylabel('Selling Price')
# Out:
# Text(0, 0.5, 'Selling Price')

# %%
#3.4 Plot a graph to show the number of cars sold in each state. Find the top three highest car selling states by having a look at the graph?

car_sold_by_state = car_df1['state'].value_counts().reset_index()

car_sold_by_state.columns = ['state', 'car_count']

car_sold_by_state
# Out:
#                 state  car_count
# 0                  fl      82945
# 1                  ca      73148
# 2                  pa      53907
# 3                  tx      45913
# 4                  ga      34750
# ..                ...        ...
# 59  3vwd17aj2fm285365          1
# 60  3vwd17aj3fm276741          1
# 61  3vwd17aj2fm258506          1
# 62  3vwd17aj4fm201708          1
# 63  3vwd17aj2fm261566          1
#
# [64 rows x 2 columns]

# %%
##3.4 Plot a graph to show the number of cars sold in each state. Find the top three highest car selling states by having a look at the graph?

plt.figure(figsize = (16,6))
plt.bar(car_sold_by_state['state'],car_sold_by_state['car_count'],color = "Green",width = 0.1)
plt.xlabel('State')
plt.ylabel('Number Of Car Sold')
plt.title('Number Of Car Sold In Each State')
# Out:
# Text(0.5, 1.0, 'Number Of Car Sold In Each State')

# %%
##3.4 Plot a graph to show the number of cars sold in each state. Find the top three highest car selling states by having a look at the graph?

top_3_states = car_sold_by_state.head(3)
top_3_states
# Out:
#   state  car_count
# 0    fl      82945
# 1    ca      73148
# 2    pa      53907

# %%
#3.5 Plot a bar graph of average selling price by condition score ranges of size 5. Give a summary of the insights.

car_df1['condition_bin5'] = pd.cut(car_df1['condition'], bins=range(0, 105, 5))
avg_price_by_cond_bin5 = car_df1.groupby('condition_bin5', observed=True)['sellingprice'].mean()
plt.figure(figsize=(10, 5))
avg_price_by_cond_bin5.plot(kind='bar', color='purple')
plt.title("Avg Price by Condition (Bins of 5)")
plt.ylabel("Avg Price")
plt.xlabel("Condition Range")
plt.tight_layout()
plt.show()

# %%
#3.6 Plot a bar graph of no. of cars sold by condition ranges of size 10. Give some insights from the graph. 

car_df1['condition_bin10'] = pd.cut(car_df1['condition'], bins=range(0, 60, 10))
cars_count_by_cond10 = car_df1['condition_bin10'].value_counts().sort_index()
plt.figure(figsize=(10, 5))
cars_count_by_cond10.plot(kind='bar', color='teal')
plt.title("Car Count by Condition (Bins of 10)")
plt.ylabel("Number of Cars")
plt.xlabel("Condition Score Range")
plt.tight_layout()
plt.show()

# %%
#3.7 Plot a box plot to show the distribution of car selling prices grouped by color. Extract insights and if required, remove outliers and plot the graph again. 

# With outliers
plt.figure(figsize=(12, 6))
sns.boxplot(data=car_df1, x='color', y='sellingprice')
plt.title("Selling Price by Car Color (With Outliers)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Remove top 1% outliers
cap = car_df1['sellingprice'].quantile(0.99)
filtered_df = car_df1[car_df1['sellingprice'] <= cap]

# Without outliers
plt.figure(figsize=(12, 6))
sns.boxplot(data=filtered_df, x='color', y='sellingprice')
plt.title("Selling Price by Car Color (Outliers Removed)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
